# %% [markdown]
# ## 1. Clean your Datasets
#
# For the first part of your project, you will apply the same data cleaning steps to your "data/control.txt" and "data/treatment.txt" files. By the end of this step, you should have two lists of floats that match the numbers you have in each respective file.
#
# You will implement your `clean_data` function in your `cleaner.py` module and import the module in the code-block below.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# TODO: import all the packages that you will need for this notebook here

import statistics as stats 
import matplotlib as plt

import cleaner.py

# %%
# TODO: read your text files into your code using file I/O

control_file = open("data/control.txt")
treatment_file = open("data/treatmnet.txt")

control_data = control_file.readlines()
treatment_data = treatment_file.readlines()

print(control_data)
print (treatment_data)

# TODO: clean both list objects that you created above using the 'clean_data' function

clean_control = cleaner.clean_data(control_data)
clean_treatments = cleaner.clean_data(control_data)

print (clean control, clean_control)
print (clean treatment, treatment_data)

# %% [markdown]
# ## 2. Explore your Datasets
#
# Now that you have your list objects created and cleaned, let's explore the descriptive statistics of these two files and make subsequent observations on our data.

# %%
# TODO: Calculate the standard deviation of both the control and treatment group

std_control_data = stats.stdev(clean_control_data)
std_control_data = stats.stdev(clean_treatment_data)

# TODO: print your findings

print(clean_control_data)
print(clean_treatment_data)

# %%
# TODO: Calculate the mean of both the control and treatment group

mean_control_data = stats.mean(clean_control_data)
mean_control_data = stats.mean(clean_treatment_data)

# TODO: print your findings

print(clean_control_data)
print(clean_treatment_data)

# %%
# TODO: Are there any outliers in your control group? (use 2 * stdev to find these outliers)

outliers_control = []
lower_bound = mean_control_data - (2* std_control_data)
upper_bound = mean_control_data + (2* std_control_data)

outlier_control= [x for x in clean_control_data if x < lower_bound or x > upper_bound]

print(outliers_control)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # TODO: Are there any outliers in your control group? (use 2 * stdev to find these outliers)
#       2
#       3 outliers_control = []
# ----> 4 lower_bound = mean_control_data - (2* std_control_data)
#       5 upper_bound = mean_control_data + (2* std_control_data)
#       6
#       7 outlier_control= [x for x in clean_control_data if x < lower_bound or x > upper_bound]
#
# NameError: name 'mean_control_data' is not defined

# %%
# TODO: Are there any outliers in your treatment group?

outliers_treatment = []

lower_bound = mean_treatment_data - (2* std_treatment_data)
upper_bound = mean_treatment_data + (2* std_treatment_data)

outlier_treatment = [x for x in clean_treatment_data if x < lower_bound or x > upper_bound]

print(outliers_treatment)

# %% [markdown]
# ## 3. Create Data Visualizations
#
# For this final step, generate data visualizations to view the dispersion of both of your groups.
#
# Make sure that the two visualizations you create are on the same figure.

# %%
# TODO: create a data visualization to view differences in dispersion and mean

import matplotlib as plt

# clean_control and clean_treatment
# create separate histograms
# on same graph

plt.hist(clean_control_data, alpha=0.8)
plt.hist(clean_treatment_data, alpha=0.8)

# create a title
plt.title ("Presentation Viewing Times B/W Contorl & Treatment")

# label y axis
plt.ylabel ("Viewing Minutes")
plt.xlabel ("NUmber of Views")


plt.show()
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       5 # clean_control and clean_treatment
#       6 # create separate histograms
#       7 # on same graph
#       8
# ----> 9 plt.hist(clean_control_data, alpha=0.8)
#      10 plt.hist(clean_treatment_data, alpha=0.8)
#      11
#      12 # create a title
#
# File /opt/miniconda3/lib/python3.13/site-packages/matplotlib/_api/__init__.py:232, in caching_module_getattr.<locals>.__getattr__(name)
#     230 if name in props:
#     231     return props[name].__get__(instance)
# --> 232 raise AttributeError(
#     233     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'hist'

# %% [markdown]
# ## 4. Your Data Findings
#
# What did you discover about your two datasets? Which group has the highest viewing time? What would you want to investigate next?

# %% [markdown]
# So technically speaking....
#
# The control group (the orginal sided) showed a wider spread in viewing times, indicating less consistent engagement across participants. The average viewing time was also lower compared to the treatment group. Additionally, this group contained more outliers, suggesting greater variability in how individuals engaged with the content.
#
# The treatment group (the revised slides) demonstrated a higher average viewing time, indicating improved overall engagement. Viewing times were also more concentrated, reflecting more consistent user behavior.This group had fewer outliers, suggesting a more stable and uniform experience across participants.
#
# Key Takeaways:
#
# The analysis shows that the revised slides (with reduced word count) led to higher and more consistent engagement compared to the original slides. Although the control group exhibited greater variability, it did not translate into stronger performance. The treatment group not only increased average viewing time but also produced more reliable engagement outcomes. These findings suggest that simplifying slide content can have a meaningful positive impact on user engagement.
#
# Additional Insight:
#
# To better understand the consistency of engagement, both variance and interquartile range (IQR) were considered. Variance captures the overall spread of the data, including extreme values, while IQR focuses on the middle 50% of observations and is less influenced by outliers.In this analysis, the control group showed greater variability, indicating less consistent engagement. The treatment group, however, demonstrated more concentrated viewing times, suggesting a more stable user experience.
# Given the presence of outliers, IQR provided a more reliable view of typical engagement behavior. This reinforces the conclusion that the redesigned slides not only increased average viewing time but also improved consistency across users.
